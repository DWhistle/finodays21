# %%
import pandas as pd
import nltk

# %%
# !pip3.8 install transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting transformers
#   Using cached transformers-4.10.2-py3-none-any.whl (2.8 MB)
# Requirement already satisfied: numpy>=1.17 in /Users/andrew/Library/Python/3.8/lib/python/site-packages (from transformers) (1.20.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/andrew/Library/Python/3.8/lib/python/site-packages (from transformers) (2021.8.28)
# Collecting pyyaml>=5.1
#   Using cached PyYAML-5.4.1.tar.gz (175 kB)
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-it0y2157/normal/lib/python3.8/site-packages
#   sysconfig: /Library/Python/3.8/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-it0y2157/normal/lib/python3.8/site-packages
#   sysconfig: /Library/Python/3.8/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-it0y2157/normal'
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-it0y2157/overlay/lib/python3.8/site-packages
#   sysconfig: /Library/Python/3.8/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-it0y2157/overlay/lib/python3.8/site-packages
#   sysconfig: /Library/Python/3.8/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-it0y2157/overlay'
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting huggingface-hub>=0.0.12
#   Using cached huggingface_hub-0.0.17-py3-none-any.whl (52 kB)
# Collecting tokenizers<0.11,>=0.10.1
#   Using cached tokenizers-0.10.3.tar.gz (212 kB)
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-ery3h72n/normal/lib/python3.8/site-packages
#   sysconfig: /Library/Python/3.8/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-ery3h72n/normal/lib/python3.8/site-packages
#   sysconfig: /Library/Python/3.8/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-ery3h72n/normal'
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-ery3h72n/overlay/lib/python3.8/site-packages
#   sysconfig: /Library/Python/3.8/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-ery3h72n/overlay/lib/python3.8/site-packages
#   sysconfig: /Library/Python/3.8/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-ery3h72n/overlay'
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Library/Developer/CommandLineTools/usr/bin/python3 /Users/andrew/Library/Python/3.8/lib/python/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/tmp4g4ga0jd
#        cwd: /private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-install-4njqsg83/tokenizers_219a18d4ca9241728377bcc157f69765
#   Complete output (30 lines):
#   Traceback (most recent call last):
#     File "/Users/andrew/Library/Python/3.8/lib/python/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 349, in <module>
#       main()
#     File "/Users/andrew/Library/Python/3.8/lib/python/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 331, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#     File "/Users/andrew/Library/Python/3.8/lib/python/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 117, in get_requires_for_build_wheel
#       return hook(config_settings)
#     File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/build_meta.py", line 146, in get_requires_for_build_wheel
#       return self._get_build_requires(config_settings, requirements=['wheel'])
#     File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/build_meta.py", line 127, in _get_build_requires
#       self.run_setup()
#     File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/build_meta.py", line 142, in run_setup
#       exec(compile(code, __file__, 'exec'), locals())
#     File "setup.py", line 7, in <module>
#       setup(
#     File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/__init__.py", line 145, in setup
#       return distutils.core.setup(**attrs)
#     File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/distutils/core.py", line 108, in setup
#       _setup_distribution = dist = klass(attrs)
#     File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/dist.py", line 445, in __init__
#       _Distribution.__init__(self, {
#     File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/distutils/dist.py", line 292, in __init__
#       self.finalize_options()
#     File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/dist.py", line 733, in finalize_options
#       ep.require(installer=self.fetch_build_egg)
#     File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages/pkg_resources/__init__.py", line 2465, in require
#       items = working_set.resolve(reqs, env, installer, extras=self.extras)
#     File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages/pkg_resources/__init__.py", line 791, in resolve
#       raise VersionConflict(dist, req).with_context(dependent_req)
#   pkg_resources.VersionConflict: (setuptools 41.2.0 (/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages), Requirement.parse('setuptools>=46.1'))
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/48/2b/b99184cacb1a743edc18290e9127d1b0e658c0c46f2ab5290b27fe865ff4/tokenizers-0.10.3.tar.gz#sha256=1a5d3b596c6d3a237e1ad7f46c472d467b0246be7fd1a364f12576eb8db8f7e6 (from https://pypi.org/simple/tokenizers/). Command errored out with exit status 1: /Library/Developer/CommandLineTools/usr/bin/python3 /Users/andrew/Library/Python/3.8/lib/python/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/tmp4g4ga0jd Check the logs for full command output.
#   Using cached tokenizers-0.10.2.tar.gz (211 kB)
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-h9p79ni9/normal/lib/python3.8/site-packages
#   sysconfig: /Library/Python/3.8/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-h9p79ni9/normal/lib/python3.8/site-packages
#   sysconfig: /Library/Python/3.8/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-h9p79ni9/normal'
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-h9p79ni9/overlay/lib/python3.8/site-packages
#   sysconfig: /Library/Python/3.8/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-h9p79ni9/overlay/lib/python3.8/site-packages
#   sysconfig: /Library/Python/3.8/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-h9p79ni9/overlay'
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Library/Developer/CommandLineTools/usr/bin/python3 /Users/andrew/Library/Python/3.8/lib/python/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/tmpqkowesx5
#        cwd: /private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-install-4njqsg83/tokenizers_a3dc57d8665247cd88f056a5b1219138
#   Complete output (30 lines):
#   Traceback (most recent call last):
#     File "/Users/andrew/Library/Python/3.8/lib/python/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 349, in <module>
#       main()
#     File "/Users/andrew/Library/Python/3.8/lib/python/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 331, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#     File "/Users/andrew/Library/Python/3.8/lib/python/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 117, in get_requires_for_build_wheel
#       return hook(config_settings)
#     File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/build_meta.py", line 146, in get_requires_for_build_wheel
#       return self._get_build_requires(config_settings, requirements=['wheel'])
#     File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/build_meta.py", line 127, in _get_build_requires
#       self.run_setup()
#     File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/build_meta.py", line 142, in run_setup
#       exec(compile(code, __file__, 'exec'), locals())
#     File "setup.py", line 7, in <module>
#       setup(
#     File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/__init__.py", line 145, in setup
#       return distutils.core.setup(**attrs)
#     File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/distutils/core.py", line 108, in setup
#       _setup_distribution = dist = klass(attrs)
#     File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/dist.py", line 445, in __init__
#       _Distribution.__init__(self, {
#     File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/distutils/dist.py", line 292, in __init__
#       self.finalize_options()
#     File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/dist.py", line 733, in finalize_options
#       ep.require(installer=self.fetch_build_egg)
#     File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages/pkg_resources/__init__.py", line 2465, in require
#       items = working_set.resolve(reqs, env, installer, extras=self.extras)
#     File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages/pkg_resources/__init__.py", line 791, in resolve
#       raise VersionConflict(dist, req).with_context(dependent_req)
#   pkg_resources.VersionConflict: (setuptools 41.2.0 (/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages), Requirement.parse('setuptools>=46.1'))
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/05/96/d8f7a202cd46ac646b0aca2f3a7902bfefc70e9bd980e0371dba7fe7db85/tokenizers-0.10.2.tar.gz#sha256=cf7f1aad957fed36e4a90fc094e3adc03fdd45fbb058c1cde25721e3e66235f8 (from https://pypi.org/simple/tokenizers/). Command errored out with exit status 1: /Library/Developer/CommandLineTools/usr/bin/python3 /Users/andrew/Library/Python/3.8/lib/python/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/tmpqkowesx5 Check the logs for full command output.
#   Using cached tokenizers-0.10.1.tar.gz (210 kB)
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-vxfrgm_m/normal/lib/python3.8/site-packages
#   sysconfig: /Library/Python/3.8/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-vxfrgm_m/normal/lib/python3.8/site-packages
#   sysconfig: /Library/Python/3.8/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-vxfrgm_m/normal'
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-vxfrgm_m/overlay/lib/python3.8/site-packages
#   sysconfig: /Library/Python/3.8/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-vxfrgm_m/overlay/lib/python3.8/site-packages
#   sysconfig: /Library/Python/3.8/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/xf/9lz0m_yx41b0t1c62sn35swc0000gn/T/pip-build-env-vxfrgm_m/overlay'
#   Installing build dependencies ... \^C
# anceled
# ERROR: Operation cancelled by user

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
  
tokenizer = AutoTokenizer.from_pretrained("sismetanin/xlm_roberta_large-ru-sentiment-rureviews")

model = AutoModelForSequenceClassification.from_pretrained("sismetanin/xlm_roberta_large-ru-sentiment-rureviews")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-5abd615b8b0a> in <module>
# ----> 1 from transformers import AutoTokenizer, AutoModelForSequenceClassification
#       2
#       3 tokenizer = AutoTokenizer.from_pretrained("sismetanin/xlm_roberta_large-ru-sentiment-rureviews")
#       4
#       5 model = AutoModelForSequenceClassification.from_pretrained("sismetanin/xlm_roberta_large-ru-sentiment-rureviews")
#
# ModuleNotFoundError: No module named 'transformers'
